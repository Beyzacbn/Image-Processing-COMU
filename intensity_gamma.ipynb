# %%
import os
os.getcwd()
os.listdir()
# Out:
# ['.anaconda',
#  '.android',
#  '.AndroidStudio3.4',
#  '.AndroidStudio3.6',
#  '.astropy',
#  '.conda',
#  '.condarc',
#  '.config',
#  '.DiaApp2',
#  '.dotnet',
#  '.emulator_console_auth_token',
#  '.gitconfig',
#  '.gradle',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '.nuget',
#  '.PyCharmCE2019.2',
#  '.QtWebEngineProcess',
#  '.RapidMiner',
#  '.spyder-py3',
#  '.templateengine',
#  '.VirtualBox',
#  '22 Ekim.ipynb',
#  '3D Objects',
#  'Anaconda3',
#  'AndroidStudioProjects',
#  'App.razor',
#  'AppData',
#  'Application Data',
#  'Belgelerim',
#  'Beyza.csproj',
#  'Cameraman.jpg',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'iCloudDrive',
#  'Intel',
#  'IntelGraphicsProfiles',
#  'intensity_gamma.ipynb',
#  'istanbul.jpg',
#  'istanbul_bw.jpg',
#  'istanbul_gray.jpg',
#  'Links',
#  'Local Settings',
#  'MicrosoftEdgeBackups',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{dcce5550-bbd7-11ea-b7ae-ec95c9b2260c}.TM.blf',
#  'NTUSER.DAT{dcce5550-bbd7-11ea-b7ae-ec95c9b2260c}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{dcce5550-bbd7-11ea-b7ae-ec95c9b2260c}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'obj',
#  'OneDrive',
#  'Pages',
#  'pemhttpd.exe',
#  'Pictures',
#  'Postman',
#  'PrintHood',
#  'Program.cs',
#  'PycharmProjects',
#  'Recent',
#  'Roaming',
#  'Saved Games',
#  'Searches',
#  'SendTo',
#  'Shared',
#  'source',
#  'Start Menu',
#  'Startup.cs',
#  'Templates',
#  'teslim.py',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'Videos',
#  'VirtualBox VMs',
#  'WebApplication2Context-99a649d0-507e-437d-85ec-c10c5e6b70ea.mdf',
#  'WebApplication2Context-99a649d0-507e-437d-85ec-c10c5e6b70ea_log.ldf',
#  'WebApplication3Context-40d3e183-1950-442b-b2ac-6d104445e9eb.mdf',
#  'WebApplication3Context-40d3e183-1950-442b-b2ac-6d104445e9eb_log.ldf',
#  'WebApplication4Context-1a4fac36-db87-4157-81da-1bb69f960522.mdf',
#  'WebApplication4Context-1a4fac36-db87-4157-81da-1bb69f960522_log.ldf',
#  'WebApplication5Context-7e6155e4-83c0-4388-8978-e1c0a159ed4e.mdf',
#  'WebApplication5Context-7e6155e4-83c0-4388-8978-e1c0a159ed4e_log.ldf',
#  'WebApplication7Context-33475acb-e21e-48bf-a2dc-6ec0b6519e3c.mdf',
#  'WebApplication7Context-33475acb-e21e-48bf-a2dc-6ec0b6519e3c_log.ldf',
#  'WebApplication8Context-3cd83f65-8e4a-4cc4-84ee-de3d6d432689.mdf',
#  'WebApplication8Context-3cd83f65-8e4a-4cc4-84ee-de3d6d432689_log.ldf',
#  'wwwroot',
#  'yenii.db',
#  '_Imports.razor']

# %%
path=r"C:\Users\Beyza"
file_name_with_path=path+"\Cameraman.jpg"

# %%
file_name_with_path
# Out:
# 'C:\\Users\\Beyza\\Cameraman.jpg'

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def convert_rgb_to_gray_level(im_1):
    m=im_1.shape[0]
    n=im_1.shape[0]
    im_2=np.zeros((m,n))
    for i in range(m):
        for j in range(n):
            im_2[i,j]=get_distance(im_1[i,j,:])
    return im_2

def get_distance(v,w=[1/3,1/3,1/3]):
    a,b,c=v[0],v[1],v[2]
    w1,w2,w3=w[0],w[1],w[2]
    d=((a**2)*w1 +
    (b**2)*w2+
    (c**2)*w3)**.5
    return d

# %%
img_0=plt.imread(file_name_with_path) 
# %matplotlib inline 
plt.imshow(img_0) 
plt.show()

# %%
img_0.ndim,img_0.shape
# Out:
# (3, (171, 295, 3))

# %%
img_1.ndim,img_1.shape
# Out:
# (2, (171, 171))

# %%
np.min(img_2),np.max(img_2)
# Out:
# (0, 0)

# %%
def my_f_1(a,b):
    assert a>=0; "intensity pozitive", "error intensity not positive"
    if(a<=255-b):
        return a+b
    else:
        return 255

# %%
img_0+10
# Out:
# array([[[192, 192, 192],
#         [192, 192, 192],
#         [193, 193, 193],
#         ...,
#         [185, 185, 185],
#         [187, 187, 187],
#         [228, 228, 228]],
#
#        [[192, 192, 192],
#         [192, 192, 192],
#         [192, 192, 192],
#         ...,
#         [185, 185, 185],
#         [187, 187, 187],
#         [228, 228, 228]],
#
#        [[192, 192, 192],
#         [192, 192, 192],
#         [192, 192, 192],
#         ...,
#         [185, 185, 185],
#         [187, 187, 187],
#         [227, 227, 227]],
#
#        ...,
#
#        [[146, 146, 146],
#         [159, 159, 159],
#         [156, 156, 156],
#         ...,
#         [170, 170, 170],
#         [158, 158, 158],
#         [221, 221, 221]],
#
#        [[147, 147, 147],
#         [160, 160, 160],
#         [159, 159, 159],
#         ...,
#         [168, 168, 168],
#         [153, 153, 153],
#         [215, 215, 215]],
#
#        [[149, 149, 149],
#         [161, 161, 161],
#         [163, 163, 163],
#         ...,
#         [166, 166, 166],
#         [148, 148, 148],
#         [208, 208, 208]]], dtype=uint8)

# %%
img_1=convert_rgb_to_gray_level(img_0)
plt.imshow(img_1,cmap='gray')
plt.show()

# %%
m,n=img_1.shape
img_2=np.zeros((m,n),dtype="uint8")

# %%
def my_f_2(a):
    return int(255-a)
my_f_2(243)
# Out:
# 12

# %%
for i in range(m):
    for j in range(n):
        
        ### increment=50
        ### print(intensity)
        intensity=img_1[i,j]
        img_2[i,j]=my_f_2(intensity)

# %%
plt.imshow(img_2,cmap='gray')
plt.show()

# %%
plt.subplot(2,2,1),plt.imshow(img_0,cmap='gray')
plt.subplot(2,2,2),plt.imshow(img_1,cmap='gray')
plt.subplot(2,2,3),plt.imshow(img_2,cmap='gray')
plt.show()

# %%
x=np.array(list(range(100)))
#y=np.array(list(range(100)))
#y=np.sin(np.array(list(range(100))))
#y=1/(1+np.exp(x))
y1=np.power(x/float(np.max(x)),1)
y2=np.power(x/float(np.max(x)),10)
y3=np.power(x/float(np.max(x)),1/10)


plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)

# %%
x=img_0
img_100=np.power(x/float(np.max(x)),10)
plt.imshow(img_100)
plt.show()
